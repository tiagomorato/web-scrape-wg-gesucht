# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from db_functions import db_query

# %% [markdown]
# # Query

# %% [markdown]
# ##### The inner query selects the top 10 districts (written as region in the query) with highest number of entries per region. The outer query is groupped by region, whereby region, average price per square meter and counts are selected.

# %%
db_data = db_query("""
    SELECT region, ROUND(AVG(price/sqm), 1), COUNT(*) 
    FROM wg_berlin_v2 
    WHERE price BETWEEN 200 AND 2000
    AND sqm >= 10
        AND region IN (
        SELECT most_entries
        FROM (
            SELECT region AS most_entries
            FROM wg_berlin_v2
            GROUP BY region
            ORDER BY COUNT(*) DESC
            LIMIT 10
        ) AS subquery_alias
    )
    GROUP BY region
    ORDER BY COUNT(*) DESC
""")
# Out:
# Rows affected:  [('Berlin', 32.7, 128), ('Neukoelln', 28.2, 93), ('Friedrichshain', 30.5, 86), ('Wedding', 28.4, 70), ('Kreuzberg', 32.8, 68), ('Mitte', 37.7, 63), ('Prenzlauer-Berg', 32.3, 62), ('Charlottenburg', 32.9, 49), ('Schoeneberg', 32.0, 43), ('Moabit', 36.8, 30)]

# %% [markdown]
# # Barplot

# %%
db_data = [x for x in db_data]
height = [value[1] for value in db_data]
bars = ([key[0] for key in db_data])
x_pos = np.arange(len(bars))

# Figure object
fig = plt.figure(figsize=(10, 8))

# Create bars
plt.bar(x_pos, height)

# Count annotations on each bar
for i, v in enumerate(height):
    plt.text(i, v+1, str(v), color='black', fontweight='bold', ha='center')

# x-axis names
plt.xticks(x_pos, bars, rotation=90)

# horizontal line for average
avg_value = np.mean(height)
plt.axhline(y=avg_value, color='r', linestyle='--')

# Custom the subplot layout
plt.subplots_adjust(bottom=0.4, top=0.99)

plt.xlabel('Districts')
plt.ylabel('Average price per square meter in €')
plt.title('Average price per square meter in Berlin')
plt.show()
# Out:
# Rows affected:  [('Berlin', 32.7, 128), ('Neukoelln', 28.2, 93), ('Friedrichshain', 30.5, 86), ('Wedding', 28.4, 70), ('Kreuzberg', 32.8, 68), ('Mitte', 37.7, 63), ('Prenzlauer-Berg', 32.3, 62), ('Charlottenburg', 32.9, 49), ('Schoeneberg', 32.0, 43), ('Moabit', 36.8, 30)]

# %% [markdown]
# # Scatterplot

# %%
db_data = db_query("""
    SELECT region, ROUND(AVG(price/sqm), 1), COUNT(*)
    FROM wg_berlin_v2
    WHERE price BETWEEN 200 AND 2000
    AND sqm >= 10
    AND region IN (
        SELECT most_entries
        FROM (
            SELECT region AS most_entries
            FROM wg_berlin_v2
            GROUP BY region
            ORDER BY COUNT(*) DESC
            LIMIT 10
        ) AS subquery_alias
    )
    GROUP BY region
    ORDER BY COUNT(*) DESC
""")
# Out:
# Rows affected:  [('Berlin', 32.7, 128), ('Neukoelln', 28.2, 93), ('Friedrichshain', 30.5, 86), ('Wedding', 28.4, 70), ('Kreuzberg', 32.8, 68), ('Mitte', 37.7, 63), ('Prenzlauer-Berg', 32.3, 62), ('Charlottenburg', 32.9, 49), ('Schoeneberg', 32.0, 43), ('Moabit', 36.8, 30)]

# %%
db_data = [x for x in db_data]

df = pd.DataFrame(db_data, columns=['District', 'Average price', 'Counts'])

sns.set_theme(style="whitegrid")
sns.relplot(x="Counts", y="Average price", hue="District", size="Counts",
            sizes=(100, 400), alpha=1, palette="muted", height=6, data=df)

# %%
db_data = db_query("""
    SELECT region, price, sqm
    FROM wg_berlin_v2 
    WHERE price BETWEEN 200 AND 2000
    AND sqm >= 10
    AND region IN (
        SELECT most_entries
        FROM (
            SELECT region AS most_entries
            FROM wg_berlin_v2
            GROUP BY region
            ORDER BY COUNT(*) DESC
            LIMIT 10
        ) AS subquery_alias
    )
    ORDER BY region;
""")


df = pd.DataFrame(db_data, columns=['district', 'price', 'sqm'])
df['district'] = df['district'].apply(str.lower)
df['price'] = pd.to_numeric(df['price'], downcast='integer')
df['sqm'] = pd.to_numeric(df['sqm'], downcast='integer')

sns.relplot(data=df, x="sqm", y="price", hue="district", col="district", col_wrap=5)
# Out:
# Rows affected:  [('Berlin', '700', '18'), ('Berlin', '650', '12'), ('Berlin', '435', '16'), ('Berlin', '550', '28'), ('Berlin', '590', '12'), ('Berlin', '795', '16'), ('Berlin', '350', '10'), ('Berlin', '650', '14'), ('Berlin', '650', '18'), ('Berlin', '880', '11'), ('Berlin', '370', '24'), ('Berlin', '500', '20'), ('Berlin', '600', '20'), ('Berlin', '650', '12'), ('Berlin', '570', '20'), ('Berlin', '900', '70'), ('Berlin', '420', '28'), ('Berlin', '510', '11'), ('Berlin', '500', '15'), ('Berlin', '550', '17'), ('Berlin', '350', '18'), ('Berlin', '650', '15'), ('Berlin', '360', '25'), ('Berlin', '600', '30'), ('Berlin', '430', '20'), ('berlin', '350', '14'), ('Berlin', '550', '15'), ('Berlin', '300', '20'), ('Berlin', '420', '13'), ('Berlin', '600', '16'), ('Berlin', '350', '20'), ('Berlin', '1000', '14'), ('Berlin', '695', '17'), ('Berlin', '600', '18'), ('Berlin', '500', '20'), ('Berlin', '450', '23'), ('Berlin', '500', '16'), ('Berlin', '500', '12'), ('Berlin', '600', '14'), ('Berlin', '550', '15'), ('Berlin', '950', '25'), ('Berlin', '690', '24'), ('Berlin', '990', '28'), ('Berlin', '700', '14'), ('Berlin', '530', '14'), ('Berlin', '680', '13'), ('Berlin', '940', '21'), ('Berlin', '750', '12'), ('Berlin', '600', '12'), ('Berlin', '510', '20'), ('Berlin', '380', '11'), ('Berlin', '499', '16'), ('Berlin', '450', '16'), ('Berlin', '500', '20'), ('Berlin', '550', '10'), ('Berlin', '388', '10'), ('Berlin', '670', '16'), ('Berlin', '450', '18'), ('Berlin', '600', '20'), ('Berlin', '530', '22'), ('Berlin', '500', '15'), ('Berlin', '600', '20'), ('Berlin', '800', '23'), ('Berlin', '480', '14'), ('Berlin', '600', '25'), ('Berlin', '695', '21'), ('Berlin', '800', '20'), ('Berlin', '260', '25'), ('Berlin', '700', '12'), ('Berlin', '519', '17'), ('Berlin', '460', '13'), ('Berlin', '600', '14'), ('Berlin', '750', '25'), ('Berlin', '800', '50'), ('Berlin', '400', '30'), ('Berlin', '600', '30'), ('Berlin', '550', '18'), ('Berlin', '560', '12'), ('berlin', '400', '14'), ('Berlin', '350', '12'), ('Berlin', '850', '30'), ('Berlin', '800', '27'), ('Berlin', '380', '20'), ('Berlin', '400', '24'), ('Berlin', '650', '20'), ('Berlin', '600', '13'), ('Berlin', '450', '12'), ('Berlin', '750', '16'), ('Berlin', '600', '18'), ('Berlin', '550', '20'), ('Berlin', '850', '19'), ('Berlin', '600', '20'), ('Berlin', '600', '15'), ('Berlin', '500', '23'), ('Berlin', '600', '21'), ('Berlin', '750', '25'), ('Berlin', '640', '33'), ('Berlin', '720', '16'), ('Berlin', '490', '25'), ('Berlin', '557', '16'), ('Berlin', '256', '16'), ('Berlin', '712', '22'), ('Berlin', '500', '15'), ('Berlin', '500', '16'), ('Berlin', '994', '52'), ('BERLIN', '490', '24'), ('Berlin', '270', '10'), ('Berlin', '450', '13'), ('Berlin', '550', '16'), ('Berlin', '560', '15'), ('Berlin', '1250', '22'), ('Berlin', '300', '16'), ('Berlin', '550', '22'), ('Berlin', '650', '23'), ('Berlin', '500', '20'), ('Berlin', '420', '14'), ('Berlin', '430', '15'), ('Berlin', '350', '20'), ('Berlin', '600', '26'), ('Berlin', '500', '16'), ('Berlin', '235', '10'), ('Berlin', '550', '21'), ('Berlin', '390', '26'), ('Berlin', '650', '21'), ('Berlin', '1000', '27'), ('Berlin', '850', '25'), ('Berlin', '900', '20'), ('Berlin', '550', '15'), ('Charlottenburg', '800', '35'), ('Charlottenburg', '450', '22'), ('Charlottenburg', '650', '27'), ('Charlottenburg', '680', '16'), ('Charlottenburg', '850', '38'), ('Charlottenburg', '650', '21'), ('Charlottenburg', '740', '20'), ('Charlottenburg', '880', '14'), ('Charlottenburg', '1520', '26'), ('Charlottenburg', '600', '20'), ('Charlottenburg', '810', '18'), ('Charlottenburg', '600', '28'), ('Charlottenburg', '220', '16'), ('Charlottenburg', '495', '13'), ('Charlottenburg', '590', '30'), ('Charlottenburg', '550', '20'), ('Charlottenburg', '656', '21'), ('Charlottenburg', '550', '25'), ('Charlottenburg', '200', '12'), ('Charlottenburg', '760', '17'), ('Charlottenburg', '500', '14'), ('Charlottenburg', '320', '21'), ('Charlottenburg', '420', '10'), ('Charlottenburg', ' ...
